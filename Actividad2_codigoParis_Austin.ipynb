# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # *Austin*

# %%
# Cargar el archivo de Austin
badf = pd.read_csv('baseaustin.csv')
badf.head()
# Out:
#      id                                               name  host_id  \
# 0  5456          Walk to 6th, Rainey St and Convention Ctr     8028
# 1  5769                                     NW Austin Room     8186
# 2  6413                      Gem of a Studio near Downtown    13879
# 3  6448  Secluded Studio @ Zilker - King Bed, Bright & ...    14156
# 4  8502                            Woodland Studio Lodging    25298
#
#    host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0     Sylvia                  NaN          78702  30.26057  -97.73441
# 1  Elizabeth                  NaN          78729  30.45697  -97.78422
# 2       Todd                  NaN          78704  30.24885  -97.73587
# 3        Amy                  NaN          78704  30.26034  -97.76487
# 4      Karen                  NaN          78741  30.23466  -97.73682
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
badf.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             2
# neighbourhood_group               15244
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                              4061
# minimum_nights                        0
# number_of_reviews                     0
# last_review                        3060
# reviews_per_month                  3060
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           15244
# dtype: int64

# %%
badf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15244 entries, 0 to 15243
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15244 non-null  int64
#  1   name                            15244 non-null  object
#  2   host_id                         15244 non-null  int64
#  3   host_name                       15242 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   15244 non-null  int64
#  6   latitude                        15244 non-null  float64
#  7   longitude                       15244 non-null  float64
#  8   room_type                       15244 non-null  object
#  9   price                           11183 non-null  float64
#  10  minimum_nights                  15244 non-null  int64
#  11  number_of_reviews               15244 non-null  int64
# ...

# %%
badf1 = badf.drop(['license', 'neighbourhood_group'], axis=1)
badf1.head()
# Out:
#      id                                               name  host_id  \
# 0  5456          Walk to 6th, Rainey St and Convention Ctr     8028
# 1  5769                                     NW Austin Room     8186
# 2  6413                      Gem of a Studio near Downtown    13879
# 3  6448  Secluded Studio @ Zilker - King Bed, Bright & ...    14156
# 4  8502                            Woodland Studio Lodging    25298
#
#    host_name  neighbourhood  latitude  longitude        room_type  price  \
# 0     Sylvia          78702  30.26057  -97.73441  Entire home/apt  111.0
# 1  Elizabeth          78729  30.45697  -97.78422     Private room    NaN
# 2       Todd          78704  30.24885  -97.73587  Entire home/apt    NaN
# 3        Amy          78704  30.26034  -97.76487  Entire home/apt  159.0
# 4      Karen          78741  30.23466  -97.73682  Entire home/apt   48.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
badf1.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            2
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                             4061
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3060
# reviews_per_month                 3060
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
badf1["price"]=badf1["price"].fillna(round(badf1["price"].mean(),1))
badf1.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            2
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3060
# reviews_per_month                 3060
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
badf21_copy = badf1.copy()

badf21_copy = badf21_copy.dropna(subset=['last_review'])

mode = badf21_copy['last_review'].mode()[0]

badf21['last_review'] = badf21['last_review'].fillna(mode)

# %%
badf21.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                            2
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                          0
# reviews_per_month                 3060
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# dtype: int64

# %%
badf21["reviews_per_month"]=badf21["reviews_per_month"].fillna(round(badf21["reviews_per_month"].mean(),1))
badf21.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         2
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %%
badf21['host_name'] = badf21['host_name'].fillna('Unknown')

# %%
badf21.to_csv('Austinclean.csv', index=False)

# %% [markdown]
# # *Paris*

# %%
# Cargar el archivo de paris
bpdf = pd.read_csv('baseparis.csv')
bpdf.head()
# Out:
#        id                                               name  host_id  \
# 0  371299  Marais Rue des Archives refait à neuf février ...  1870265
# 1  371862                         loft in Paris (Belleville)  1872631
# 2  372879            Appartement complet au centre de Paris.  1876396
# 3  375434  Luxurious Art & Design Flat, 180m2, Champs Ely...   683140
# 4  378897                        Little flat near Montmartre  1902818
#
#    host_name  neighbourhood_group   neighbourhood  latitude  longitude  \
# 0     Thomas                  NaN  Hôtel-de-Ville  48.85751    2.35511
# 1  Veronique                  NaN        Entrepôt  48.87151    2.37219
# 2     Samuel                  NaN        Gobelins  48.83593    2.35108
# 3      Oscar                  NaN          Élysée  48.86680    2.30972
# 4   Lorraine                  NaN           Opéra  48.88285    2.33462
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
bpdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95461 entries, 0 to 95460
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              95461 non-null  int64
#  1   name                            95461 non-null  object
#  2   host_id                         95461 non-null  int64
#  3   host_name                       95455 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   95461 non-null  object
#  6   latitude                        95461 non-null  float64
#  7   longitude                       95461 non-null  float64
#  8   room_type                       95461 non-null  object
#  9   price                           64230 non-null  float64
#  10  minimum_nights                  95461 non-null  int64
#  11  number_of_reviews               95461 non-null  int64
# ...

# %%
bpdf1 = bpdf.drop(['license', 'neighbourhood_group'], axis=1)
bpdf1.head()
# Out:
#        id                                               name  host_id  \
# 0  371299  Marais Rue des Archives refait à neuf février ...  1870265
# 1  371862                         loft in Paris (Belleville)  1872631
# 2  372879            Appartement complet au centre de Paris.  1876396
# 3  375434  Luxurious Art & Design Flat, 180m2, Champs Ely...   683140
# 4  378897                        Little flat near Montmartre  1902818
#
#    host_name   neighbourhood  latitude  longitude        room_type  price  \
# 0     Thomas  Hôtel-de-Ville  48.85751    2.35511  Entire home/apt  185.0
# 1  Veronique        Entrepôt  48.87151    2.37219  Entire home/apt  250.0
# 2     Samuel        Gobelins  48.83593    2.35108  Entire home/apt   85.0
# 3      Oscar          Élysée  48.86680    2.30972  Entire home/apt    NaN
# 4   Lorraine           Opéra  48.88285    2.33462  Entire home/apt  110.0
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
bpdf1.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             6
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             31231
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       27142
# reviews_per_month                 27142
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# dtype: int64

# %%
bpdf1["price"]=bpdf1["price"].fillna(round(bpdf1["price"].mean(),1))
bpdf1.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             6
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       27142
# reviews_per_month                 27142
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# dtype: int64

# %%
bpdf21_copy = bpdf1.copy()

bpdf21_copy = bpdf21_copy.dropna(subset=['last_review'])

mode = bpdf21_copy['last_review'].mode()[0]

bpdf1['last_review'] = bpdf1['last_review'].fillna(mode)

# %%
bpdf1.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             6
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                 27142
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# dtype: int64

# %%
bpdf1["reviews_per_month"]=bpdf1["reviews_per_month"].fillna(round(bpdf1["reviews_per_month"].mean(),1))
bpdf1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         6
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %%
bpdf1['host_name'] = bpdf1['host_name'].fillna('Unknown')
bpdf1.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %%
bpdf1.to_csv('Parisclean.csv', index=False)
